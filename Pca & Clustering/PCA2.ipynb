# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_breast_cancer
cancer=load_breast_cancer()

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
df=pd.DataFrame(cancer.data,columns=cancer.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)

# %%
scaled_data
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
da=pd.DataFrame(scaled_data,columns=cancer.feature_names)
da
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2,)
pca_da=pca.fit_transform(da)
pca_da
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.6720101 ],
#        [-5.4752433 , -0.67063679]])

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
df.shape
# Out:
# (569, 30)

# %%
pca_da[0]
# Out:
# array([9.19283683, 1.94858307])

# %%
pca_da.shape
# Out:
# (569, 2)

# %%
plt.figure(figsize=(8,6))
plt.scatter(pca_da[:,0],pca_da[:,1],c=cancer.target)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=pca_da[:,0],y=pca_da[:,1],hue=cancer.target)

# %%
plt.figure(figsize=(8,6))
plt.scatter(pca.components_[0],pca.components_[1])

# %%
sns.heatmap(pca.components_)

# %%
pca.components_.T.shape
# Out:
# (30, 2)

# %%
x_recover=pca.inverse_transform(pca_da)

# %%
pd.DataFrame(x_recover,columns=cancer.feature_names)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       1.556644      0.837181        1.672414   1.581299         1.673460
# 1       1.403909      0.472657        1.354154   1.398429        -0.360830
# 2       1.506601      0.658940        1.536033   1.515610         0.617491
# 3      -0.843788      0.125310       -0.590378  -0.800312         2.928081
# 4       1.317018      0.524499        1.314617   1.319836         0.198572
# ..           ...           ...             ...        ...              ...
# 564     2.246046      0.881473        2.234849   2.249576         0.252488
# 565     1.668536      0.607456        1.634356   1.666508        -0.126141
# 566     0.719846      0.243875        0.695166   0.717186        -0.174924
# 567     1.880056      0.976292        2.000867   1.906415         1.790522
# 568    -1.041711     -0.527876       -1.101514  -1.055033        -0.905528
#
# ...

# %%
pca.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947]])

# %%
com=pca.components_
f=com[:2]
f
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947]])

# %%
pd.DataFrame(pca.components_)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.218902  0.103725  0.227537  0.220995  0.142590  0.239285  0.258400
# 1 -0.233857 -0.059706 -0.215181 -0.231077  0.186113  0.151892  0.060165
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.260854  0.138167  0.064363  ...  0.227997  0.104469  0.236640  0.224871
# 1 -0.034768  0.190349  0.366575  ... -0.219866 -0.045467 -0.199878 -0.219352
#
#          24        25        26        27        28        29
# 0  0.127953  0.210096  0.228768  0.250886  0.122905  0.131784
# 1  0.172304  0.143593  0.097964 -0.008257  0.141883  0.275339
#
# [2 rows x 30 columns]

# %%
from sklearn.manifold import TSNE
tsne=TSNE()
tsne_d=tsne.fit_transform(scaled_data)

# %%
tsne_d
# Out:
# array([[ 35.343616 ,  11.870089 ],
#        [ 24.246355 ,   3.1246643],
#        [ 30.651613 ,   8.352506 ],
#        ...,
#        [ 14.510359 ,   6.947286 ],
#        [ 37.430767 ,   9.974011 ],
#        [-27.153803 ,   2.216274 ]], dtype=float32)

# %%
plt.figure(figsize=(20,20))
ax1=plt.subplot(2,2,1)
ax1.scatter(tsne_d[:,0],tsne_d[:,1],c=cancer.target)
ax2=plt.subplot(2,2,2)
ax2.scatter(pca_da[:,0],pca_da[:,1],c=cancer.target)

# %%
from sklearn.manifold import LocallyLinearEmbedding
le=LocallyLinearEmbedding(n_components=2,n_neighbors=10)
le_d=le.fit_transform(scaled_data)
le_d
# Out:
# array([[ 0.05372095, -0.04907943],
#        [-0.01786278,  0.01591014],
#        [-0.02193938, -0.01696012],
#        ...,
#        [-0.00630096, -0.00861067],
#        [-0.1258802 , -0.07263774],
#        [ 0.02946099,  0.00666723]])

# %%
plt.scatter(le_d[:,0],le_d[:,1],c=cancer.target)

# %%
from sklearn.ensemble import AdaBoostClassifier
gb=AdaBoostClassifier()
