# %%
from keras.models import Sequential

# %%
from keras.layers import Dense,Dropout,ReLU

# %%
classifier=Sequential()

# %%
from keras.optimizers import Adam

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Anaconda\envs\deeplearning
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.1.3               |   py37ha925a31_0         7.3 MB
#     ------------------------------------------------------------
#                                            Total:         7.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             pkgs/main/win-64::pandas-1.1.3-py37ha925a31_0
#
#
#
# Downloading and Extracting Packages
#
# pandas-1.1.3         | 7.3 MB    |            |   0%
# pandas-1.1.3         | 7.3 MB    |            |   0%
# pandas-1.1.3         | 7.3 MB    | 1          |   1%
# pandas-1.1.3         | 7.3 MB    | 1          |   2%
# pandas-1.1.3         | 7.3 MB    | 3          |   4%
# pandas-1.1.3         | 7.3 MB    | 5          |   6%
# pandas-1.1.3         | 7.3 MB    | 7          |   7%
# pandas-1.1.3         | 7.3 MB    | 8          |   9%
# pandas-1.1.3         | 7.3 MB    | #          |  11%
# pandas-1.1.3         | 7.3 MB    | #2         |  12%
# pandas-1.1.3         | 7.3 MB    | #4         |  14%
# pandas-1.1.3         | 7.3 MB    | #6         |  16%
# pandas-1.1.3         | 7.3 MB    | #8         |  18%
# pandas-1.1.3         | 7.3 MB    | #9         |  19%
# pandas-1.1.3         | 7.3 MB    | ##         |  21%
# pandas-1.1.3         | 7.3 MB    | ##2        |  22%
# pandas-1.1.3         | 7.3 MB    | ##3        |  23%
# pandas-1.1.3         | 7.3 MB    | ##5        |  25%
# pandas-1.1.3         | 7.3 MB    | ##7        |  28%
# pandas-1.1.3         | 7.3 MB    | ##9        |  29%
# pandas-1.1.3         | 7.3 MB    | ###1       |  31%
# pandas-1.1.3         | 7.3 MB    | ###2       |  33%
# pandas-1.1.3         | 7.3 MB    | ###4       |  34%
# pandas-1.1.3         | 7.3 MB    | ###5       |  36%
# pandas-1.1.3         | 7.3 MB    | ###7       |  38%
# pandas-1.1.3         | 7.3 MB    | ###9       |  39%
# pandas-1.1.3         | 7.3 MB    | ####1      |  41%
# pandas-1.1.3         | 7.3 MB    | ####3      |  43%
# pandas-1.1.3         | 7.3 MB    | ####4      |  45%
# pandas-1.1.3         | 7.3 MB    | ####6      |  46%
# pandas-1.1.3         | 7.3 MB    | ####8      |  48%
# pandas-1.1.3         | 7.3 MB    | #####      |  50%
# pandas-1.1.3         | 7.3 MB    | #####1     |  52%
# pandas-1.1.3         | 7.3 MB    | #####3     |  54%
# pandas-1.1.3         | 7.3 MB    | #####5     |  55%
# pandas-1.1.3         | 7.3 MB    | #####6     |  57%
# pandas-1.1.3         | 7.3 MB    | #####8     |  58%
# pandas-1.1.3         | 7.3 MB    | #####9     |  59%
# pandas-1.1.3         | 7.3 MB    | ######     |  61%
# pandas-1.1.3         | 7.3 MB    | ######1    |  62%
# pandas-1.1.3         | 7.3 MB    | ######2    |  63%
# pandas-1.1.3         | 7.3 MB    | ######4    |  65%
# pandas-1.1.3         | 7.3 MB    | ######5    |  66%
# pandas-1.1.3         | 7.3 MB    | ######7    |  67%
# pandas-1.1.3         | 7.3 MB    | ######8    |  68%
# pandas-1.1.3         | 7.3 MB    | ######9    |  69%
# pandas-1.1.3         | 7.3 MB    | #######    |  70%
# pandas-1.1.3         | 7.3 MB    | #######1   |  72%
# pandas-1.1.3         | 7.3 MB    | #######3   |  73%
# pandas-1.1.3         | 7.3 MB    | #######4   |  74%
# pandas-1.1.3         | 7.3 MB    | #######5   |  76%
# pandas-1.1.3         | 7.3 MB    | #######7   |  77%
# pandas-1.1.3         | 7.3 MB    | #######8   |  78%
# pandas-1.1.3         | 7.3 MB    | #######9   |  79%
# pandas-1.1.3         | 7.3 MB    | ########   |  81%
# pandas-1.1.3         | 7.3 MB    | ########1  |  82%
# pandas-1.1.3         | 7.3 MB    | ########3  |  83%
# pandas-1.1.3         | 7.3 MB    | ########4  |  85%
# pandas-1.1.3         | 7.3 MB    | ########6  |  87%
# pandas-1.1.3         | 7.3 MB    | ########8  |  88%
# pandas-1.1.3         | 7.3 MB    | #########  |  90%
# pandas-1.1.3         | 7.3 MB    | #########1 |  92%
# pandas-1.1.3         | 7.3 MB    | #########3 |  94%
# pandas-1.1.3         | 7.3 MB    | #########5 |  95%
# pandas-1.1.3         | 7.3 MB    | #########6 |  97%
# pandas-1.1.3         | 7.3 MB    | #########8 |  98%
# pandas-1.1.3         | 7.3 MB    | #########9 | 100%
# pandas-1.1.3         | 7.3 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Anaconda\envs\deeplearning
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |           py37_0          13 KB
#     freetype-2.10.4            |       hd328e21_0         466 KB
#     kiwisolver-1.3.0           |   py37hd77b12b_0          52 KB
#     lz4-c-1.9.2                |       hf4a77e7_3         106 KB
#     matplotlib-3.3.2           |                0          25 KB
#     matplotlib-base-3.3.2      |   py37hba9282a_0         5.1 MB
#     olefile-0.46               |           py37_0          49 KB
#     pillow-8.0.1               |   py37h4fa10fc_0         662 KB
#     zstd-1.4.5                 |       h04227a9_0         456 KB
#     ------------------------------------------------------------
#                                            Total:         6.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/win-64::cycler-0.10.0-py37_0
#   freetype           pkgs/main/win-64::freetype-2.10.4-hd328e21_0
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.3.0-py37hd77b12b_0
#   libtiff            pkgs/main/win-64::libtiff-4.1.0-h56a325e_1
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.2-hf4a77e7_3
#   matplotlib         pkgs/main/win-64::matplotlib-3.3.2-0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.3.2-py37hba9282a_0
#   olefile            pkgs/main/win-64::olefile-0.46-py37_0
#   pillow             pkgs/main/win-64::pillow-8.0.1-py37h4fa10fc_0
#   tk                 pkgs/main/win-64::tk-8.6.10-he774522_0
#   xz                 pkgs/main/win-64::xz-5.2.5-h62dcd97_0
#   zstd               pkgs/main/win-64::zstd-1.4.5-h04227a9_0
#
#
#
# Downloading and Extracting Packages
#
# olefile-0.46         | 49 KB     |            |   0%
# olefile-0.46         | 49 KB     | ###2       |  33%
# olefile-0.46         | 49 KB     | ########## | 100%
# olefile-0.46         | 49 KB     | ########## | 100%
#
# freetype-2.10.4      | 466 KB    |            |   0%
# freetype-2.10.4      | 466 KB    | 3          |   3%
# freetype-2.10.4      | 466 KB    | #3         |  14%
# freetype-2.10.4      | 466 KB    | ###4       |  34%
# freetype-2.10.4      | 466 KB    | ####8      |  48%
# freetype-2.10.4      | 466 KB    | ######1    |  62%
# freetype-2.10.4      | 466 KB    | #######5   |  75%
# freetype-2.10.4      | 466 KB    | #########2 |  93%
# freetype-2.10.4      | 466 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | 2          |   2%
# matplotlib-base-3.3. | 5.1 MB    | 5          |   6%
# matplotlib-base-3.3. | 5.1 MB    | 7          |   8%
# matplotlib-base-3.3. | 5.1 MB    | 9          |   9%
# matplotlib-base-3.3. | 5.1 MB    | #1         |  11%
# matplotlib-base-3.3. | 5.1 MB    | #3         |  14%
# matplotlib-base-3.3. | 5.1 MB    | #5         |  16%
# matplotlib-base-3.3. | 5.1 MB    | #7         |  18%
# matplotlib-base-3.3. | 5.1 MB    | ##         |  20%
# matplotlib-base-3.3. | 5.1 MB    | ##1        |  22%
# matplotlib-base-3.3. | 5.1 MB    | ##3        |  24%
# matplotlib-base-3.3. | 5.1 MB    | ##5        |  26%
# matplotlib-base-3.3. | 5.1 MB    | ##7        |  28%
# matplotlib-base-3.3. | 5.1 MB    | ##9        |  29%
# matplotlib-base-3.3. | 5.1 MB    | ###1       |  31%
# matplotlib-base-3.3. | 5.1 MB    | ###3       |  33%
# matplotlib-base-3.3. | 5.1 MB    | ###4       |  35%
# matplotlib-base-3.3. | 5.1 MB    | ###7       |  37%
# matplotlib-base-3.3. | 5.1 MB    | ###8       |  39%
# matplotlib-base-3.3. | 5.1 MB    | ####       |  41%
# matplotlib-base-3.3. | 5.1 MB    | ####2      |  43%
# matplotlib-base-3.3. | 5.1 MB    | ####4      |  44%
# matplotlib-base-3.3. | 5.1 MB    | ####6      |  46%
# matplotlib-base-3.3. | 5.1 MB    | ####8      |  48%
# matplotlib-base-3.3. | 5.1 MB    | #####      |  50%
# matplotlib-base-3.3. | 5.1 MB    | #####1     |  52%
# matplotlib-base-3.3. | 5.1 MB    | #####3     |  54%
# matplotlib-base-3.3. | 5.1 MB    | #####5     |  56%
# matplotlib-base-3.3. | 5.1 MB    | #####9     |  59%
# matplotlib-base-3.3. | 5.1 MB    | ######3    |  63%
# matplotlib-base-3.3. | 5.1 MB    | ######6    |  66%
# matplotlib-base-3.3. | 5.1 MB    | ######9    |  69%
# matplotlib-base-3.3. | 5.1 MB    | #######1   |  72%
# matplotlib-base-3.3. | 5.1 MB    | #######3   |  74%
# matplotlib-base-3.3. | 5.1 MB    | #######5   |  76%
# matplotlib-base-3.3. | 5.1 MB    | #######7   |  77%
# matplotlib-base-3.3. | 5.1 MB    | #######8   |  79%
# matplotlib-base-3.3. | 5.1 MB    | ########   |  80%
# matplotlib-base-3.3. | 5.1 MB    | ########1  |  81%
# matplotlib-base-3.3. | 5.1 MB    | ########2  |  83%
# matplotlib-base-3.3. | 5.1 MB    | ########3  |  84%
# matplotlib-base-3.3. | 5.1 MB    | ########4  |  85%
# matplotlib-base-3.3. | 5.1 MB    | ########6  |  86%
# matplotlib-base-3.3. | 5.1 MB    | ########7  |  87%
# matplotlib-base-3.3. | 5.1 MB    | ########8  |  89%
# matplotlib-base-3.3. | 5.1 MB    | ########9  |  90%
# matplotlib-base-3.3. | 5.1 MB    | #########  |  91%
# matplotlib-base-3.3. | 5.1 MB    | #########1 |  92%
# matplotlib-base-3.3. | 5.1 MB    | #########2 |  93%
# matplotlib-base-3.3. | 5.1 MB    | #########3 |  94%
# matplotlib-base-3.3. | 5.1 MB    | #########4 |  95%
# matplotlib-base-3.3. | 5.1 MB    | #########5 |  96%
# matplotlib-base-3.3. | 5.1 MB    | #########7 |  97%
# matplotlib-base-3.3. | 5.1 MB    | #########8 |  99%
# matplotlib-base-3.3. | 5.1 MB    | #########9 | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# kiwisolver-1.3.0     | 52 KB     |            |   0%
# kiwisolver-1.3.0     | 52 KB     | ###        |  31%
# kiwisolver-1.3.0     | 52 KB     | ######1    |  62%
# kiwisolver-1.3.0     | 52 KB     | ########## | 100%
# kiwisolver-1.3.0     | 52 KB     | ########## | 100%
#
# matplotlib-3.3.2     | 25 KB     |            |   0%
# matplotlib-3.3.2     | 25 KB     | ######4    |  65%
# matplotlib-3.3.2     | 25 KB     | ########## | 100%
# matplotlib-3.3.2     | 25 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 106 KB    |            |   0%
# lz4-c-1.9.2          | 106 KB    | #5         |  15%
# lz4-c-1.9.2          | 106 KB    | ###        |  30%
# lz4-c-1.9.2          | 106 KB    | ####5      |  45%
# lz4-c-1.9.2          | 106 KB    | ######     |  60%
# lz4-c-1.9.2          | 106 KB    | #######5   |  76%
# lz4-c-1.9.2          | 106 KB    | #########  |  91%
# lz4-c-1.9.2          | 106 KB    | ########## | 100%
# lz4-c-1.9.2          | 106 KB    | ########## | 100%
#
# pillow-8.0.1         | 662 KB    |            |   0%
# pillow-8.0.1         | 662 KB    | 2          |   2%
# pillow-8.0.1         | 662 KB    | 4          |   5%
# pillow-8.0.1         | 662 KB    | 7          |   7%
# pillow-8.0.1         | 662 KB    | 9          |  10%
# pillow-8.0.1         | 662 KB    | #2         |  12%
# pillow-8.0.1         | 662 KB    | #4         |  15%
# pillow-8.0.1         | 662 KB    | #6         |  17%
# pillow-8.0.1         | 662 KB    | #9         |  19%
# pillow-8.0.1         | 662 KB    | ##1        |  22%
# pillow-8.0.1         | 662 KB    | ##4        |  24%
# pillow-8.0.1         | 662 KB    | ##6        |  27%
# pillow-8.0.1         | 662 KB    | ##9        |  29%
# pillow-8.0.1         | 662 KB    | ###1       |  31%
# pillow-8.0.1         | 662 KB    | ###3       |  34%
# pillow-8.0.1         | 662 KB    | ###6       |  36%
# pillow-8.0.1         | 662 KB    | ###8       |  39%
# pillow-8.0.1         | 662 KB    | ####1      |  41%
# pillow-8.0.1         | 662 KB    | ####3      |  44%
# pillow-8.0.1         | 662 KB    | ####5      |  46%
# pillow-8.0.1         | 662 KB    | ####8      |  48%
# pillow-8.0.1         | 662 KB    | #####      |  51%
# pillow-8.0.1         | 662 KB    | #####3     |  53%
# pillow-8.0.1         | 662 KB    | #####5     |  56%
# pillow-8.0.1         | 662 KB    | #####8     |  58%
# pillow-8.0.1         | 662 KB    | ######     |  60%
# pillow-8.0.1         | 662 KB    | ######2    |  63%
# pillow-8.0.1         | 662 KB    | #######    |  70%
# pillow-8.0.1         | 662 KB    | #######2   |  73%
# pillow-8.0.1         | 662 KB    | #######4   |  75%
# pillow-8.0.1         | 662 KB    | #######7   |  77%
# pillow-8.0.1         | 662 KB    | #######9   |  80%
# pillow-8.0.1         | 662 KB    | ########2  |  82%
# pillow-8.0.1         | 662 KB    | ########4  |  85%
# pillow-8.0.1         | 662 KB    | ########7  |  87%
# pillow-8.0.1         | 662 KB    | ########9  |  89%
# pillow-8.0.1         | 662 KB    | #########1 |  92%
# pillow-8.0.1         | 662 KB    | #########4 |  94%
# pillow-8.0.1         | 662 KB    | #########6 |  97%
# pillow-8.0.1         | 662 KB    | ########## | 100%
# pillow-8.0.1         | 662 KB    | ########## | 100%
#
# zstd-1.4.5           | 456 KB    |            |   0%
# zstd-1.4.5           | 456 KB    | 3          |   4%
# zstd-1.4.5           | 456 KB    | 7          |   7%
# zstd-1.4.5           | 456 KB    | #          |  11%
# zstd-1.4.5           | 456 KB    | #4         |  14%
# zstd-1.4.5           | 456 KB    | #7         |  18%
# zstd-1.4.5           | 456 KB    | ##1        |  21%
# zstd-1.4.5           | 456 KB    | ##4        |  25%
# zstd-1.4.5           | 456 KB    | ##8        |  28%
# zstd-1.4.5           | 456 KB    | ###1       |  32%
# zstd-1.4.5           | 456 KB    | ###5       |  35%
# zstd-1.4.5           | 456 KB    | ###8       |  39%
# zstd-1.4.5           | 456 KB    | ####2      |  42%
# zstd-1.4.5           | 456 KB    | ####5      |  46%
# zstd-1.4.5           | 456 KB    | ####9      |  49%
# zstd-1.4.5           | 456 KB    | #####6     |  56%
# zstd-1.4.5           | 456 KB    | #####9     |  60%
# zstd-1.4.5           | 456 KB    | ######3    |  63%
# zstd-1.4.5           | 456 KB    | ######6    |  67%
# zstd-1.4.5           | 456 KB    | #######    |  70%
# zstd-1.4.5           | 456 KB    | #######3   |  74%
# zstd-1.4.5           | 456 KB    | #######7   |  77%
# zstd-1.4.5           | 456 KB    | ########4  |  84%
# zstd-1.4.5           | 456 KB    | ########7  |  88%
# zstd-1.4.5           | 456 KB    | #########1 |  91%
# zstd-1.4.5           | 456 KB    | #########4 |  95%
# zstd-1.4.5           | 456 KB    | ########## | 100%
# zstd-1.4.5           | 456 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Anaconda\envs\deeplearning
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-0.17.0              |             py_0         206 KB
#     scikit-learn-0.23.2        |   py37h47e9c7a_0         4.6 MB
#     ------------------------------------------------------------
#                                            Total:         4.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             pkgs/main/noarch::joblib-0.17.0-py_0
#   scikit-learn       pkgs/main/win-64::scikit-learn-0.23.2-py37h47e9c7a_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
#
# joblib-0.17.0        | 206 KB    |            |   0%
# joblib-0.17.0        | 206 KB    | 7          |   8%
# joblib-0.17.0        | 206 KB    | ####6      |  47%
# joblib-0.17.0        | 206 KB    | ########5  |  85%
# joblib-0.17.0        | 206 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 4.6 MB    |            |   0%
# scikit-learn-0.23.2  | 4.6 MB    |            |   0%
# scikit-learn-0.23.2  | 4.6 MB    | 2          |   2%
# scikit-learn-0.23.2  | 4.6 MB    | 3          |   4%
# scikit-learn-0.23.2  | 4.6 MB    | 5          |   5%
# scikit-learn-0.23.2  | 4.6 MB    | 6          |   7%
# scikit-learn-0.23.2  | 4.6 MB    | 8          |   9%
# scikit-learn-0.23.2  | 4.6 MB    | #          |  11%
# scikit-learn-0.23.2  | 4.6 MB    | #2         |  13%
# scikit-learn-0.23.2  | 4.6 MB    | #4         |  14%
# scikit-learn-0.23.2  | 4.6 MB    | #6         |  17%
# scikit-learn-0.23.2  | 4.6 MB    | #9         |  19%
# scikit-learn-0.23.2  | 4.6 MB    | ##1        |  21%
# scikit-learn-0.23.2  | 4.6 MB    | ##4        |  25%
# scikit-learn-0.23.2  | 4.6 MB    | ##7        |  27%
# scikit-learn-0.23.2  | 4.6 MB    | ##9        |  30%
# scikit-learn-0.23.2  | 4.6 MB    | ###1       |  32%
# scikit-learn-0.23.2  | 4.6 MB    | ###3       |  33%
# scikit-learn-0.23.2  | 4.6 MB    | ###4       |  35%
# scikit-learn-0.23.2  | 4.6 MB    | ###6       |  36%
# scikit-learn-0.23.2  | 4.6 MB    | ###7       |  37%
# scikit-learn-0.23.2  | 4.6 MB    | ###8       |  38%
# scikit-learn-0.23.2  | 4.6 MB    | ###9       |  39%
# scikit-learn-0.23.2  | 4.6 MB    | ####       |  40%
# scikit-learn-0.23.2  | 4.6 MB    | ####       |  41%
# scikit-learn-0.23.2  | 4.6 MB    | ####1      |  42%
# scikit-learn-0.23.2  | 4.6 MB    | ####2      |  43%
# scikit-learn-0.23.2  | 4.6 MB    | ####3      |  43%
# scikit-learn-0.23.2  | 4.6 MB    | ####3      |  44%
# scikit-learn-0.23.2  | 4.6 MB    | ####4      |  45%
# scikit-learn-0.23.2  | 4.6 MB    | ####5      |  45%
# scikit-learn-0.23.2  | 4.6 MB    | ####5      |  46%
# scikit-learn-0.23.2  | 4.6 MB    | ####6      |  47%
# scikit-learn-0.23.2  | 4.6 MB    | ####7      |  47%
# scikit-learn-0.23.2  | 4.6 MB    | ####7      |  48%
# scikit-learn-0.23.2  | 4.6 MB    | ####8      |  49%
# scikit-learn-0.23.2  | 4.6 MB    | ####9      |  49%
# scikit-learn-0.23.2  | 4.6 MB    | #####      |  50%
# scikit-learn-0.23.2  | 4.6 MB    | #####      |  51%
# scikit-learn-0.23.2  | 4.6 MB    | #####1     |  51%
# scikit-learn-0.23.2  | 4.6 MB    | #####2     |  52%
# scikit-learn-0.23.2  | 4.6 MB    | #####2     |  53%
# scikit-learn-0.23.2  | 4.6 MB    | #####3     |  53%
# scikit-learn-0.23.2  | 4.6 MB    | #####4     |  54%
# scikit-learn-0.23.2  | 4.6 MB    | #####4     |  55%
# scikit-learn-0.23.2  | 4.6 MB    | #####5     |  55%
# scikit-learn-0.23.2  | 4.6 MB    | #####6     |  56%
# scikit-learn-0.23.2  | 4.6 MB    | #####6     |  57%
# scikit-learn-0.23.2  | 4.6 MB    | #####7     |  57%
# scikit-learn-0.23.2  | 4.6 MB    | #####8     |  59%
# scikit-learn-0.23.2  | 4.6 MB    | #####9     |  60%
# scikit-learn-0.23.2  | 4.6 MB    | ######     |  61%
# scikit-learn-0.23.2  | 4.6 MB    | ######1    |  62%
# scikit-learn-0.23.2  | 4.6 MB    | ######2    |  63%
# scikit-learn-0.23.2  | 4.6 MB    | ######3    |  64%
# scikit-learn-0.23.2  | 4.6 MB    | ######4    |  65%
# scikit-learn-0.23.2  | 4.6 MB    | ######5    |  66%
# scikit-learn-0.23.2  | 4.6 MB    | ######6    |  67%
# scikit-learn-0.23.2  | 4.6 MB    | ######8    |  68%
# scikit-learn-0.23.2  | 4.6 MB    | ######9    |  70%
# scikit-learn-0.23.2  | 4.6 MB    | #######1   |  71%
# scikit-learn-0.23.2  | 4.6 MB    | #######3   |  73%
# scikit-learn-0.23.2  | 4.6 MB    | #######4   |  74%
# scikit-learn-0.23.2  | 4.6 MB    | #######5   |  76%
# scikit-learn-0.23.2  | 4.6 MB    | #######7   |  77%
# scikit-learn-0.23.2  | 4.6 MB    | #######8   |  79%
# scikit-learn-0.23.2  | 4.6 MB    | #######9   |  80%
# scikit-learn-0.23.2  | 4.6 MB    | ########   |  81%
# scikit-learn-0.23.2  | 4.6 MB    | ########1  |  82%
# scikit-learn-0.23.2  | 4.6 MB    | ########2  |  83%
# scikit-learn-0.23.2  | 4.6 MB    | ########4  |  84%
# scikit-learn-0.23.2  | 4.6 MB    | ########5  |  85%
# scikit-learn-0.23.2  | 4.6 MB    | ########6  |  86%
# scikit-learn-0.23.2  | 4.6 MB    | ########7  |  87%
# scikit-learn-0.23.2  | 4.6 MB    | ########8  |  89%
# scikit-learn-0.23.2  | 4.6 MB    | ########9  |  90%
# scikit-learn-0.23.2  | 4.6 MB    | #########  |  91%
# scikit-learn-0.23.2  | 4.6 MB    | #########1 |  92%
# scikit-learn-0.23.2  | 4.6 MB    | #########3 |  93%
# scikit-learn-0.23.2  | 4.6 MB    | #########4 |  95%
# scikit-learn-0.23.2  | 4.6 MB    | #########5 |  96%
# scikit-learn-0.23.2  | 4.6 MB    | #########7 |  97%
# scikit-learn-0.23.2  | 4.6 MB    | #########8 |  99%
# scikit-learn-0.23.2  | 4.6 MB    | ########## | 100%
# scikit-learn-0.23.2  | 4.6 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Executing transaction: ...working... done

# %%
import seaborn as sns
